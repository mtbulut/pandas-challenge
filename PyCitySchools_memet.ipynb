# %%
import pandas as pd
import os
import numpy as np

# %%
student_csv = os.path.join("PyCitySchools/Resources", "students_complete.csv")
school_csv = os.path.join("PyCitySchools/Resources", "schools_complete.csv")

# %%
student_df = pd.read_csv(student_csv)

# %%
# student_df

# %%
school_df = pd.read_csv(school_csv)
# school_df

# %%
df = pd.merge(student_df, school_df, on = "school_name")

# %% [markdown]
# ### District Summary

# %% [markdown]
# #####   * Total Schools
# #####   * Total Students
# #####   * Total Budget
# #####   * Average Math Score
# #####   * Average Reading Score
# #####   * % Passing Math (70 or greater)
# #####  * % Passing Reading (70 or greater)
# #####   * Overall Passing Rate (Average of the above two)

# %%
d_df = pd.DataFrame({
    "Total Schools":[len(df['school_name'].unique())],
    "Total Students": [df['student_name'].count()],
    "Total Budget": [df['budget'].unique().sum()],
    "Average Math Score": [df['math_score'].mean().round(2)],
    'Average Reading Score': [df['reading_score'].mean().round(2)],
    '% Passing Math':[((df[df['math_score']>=70]['math_score'].count()/df['student_name'].count())*100).round(2)],
    "% Passing Reading":[((df[df['reading_score']>=70]['reading_score'].count()/df['student_name'].count())*100).round(2)],
    "% Overall Passing Rate":[((((df[df['math_score']>=70]['math_score'].count()/df['student_name'].count())*100) + 
                              ((df[df['reading_score']>=70]['reading_score'].count()/df['student_name'].count())*100))/2).round(2)]   
})

# %%
d_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428               78.99
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0                  81.88           74.98              85.81
#
#    % Overall Passing Rate
# 0                   80.39

# %% [markdown]
# ### School Summary
#
# ##### * Create an overview table that summarizes key metrics about each school, including:
# #####  * School Name
# #####  * School Type
# #####  * Total Students
# #####  * Total School Budget
# #####  * Per Student Budget
# #####  * Average Math Score
# #####  * Average Reading Score
# #####  * % Passing Math
# #####  * % Passing Reading
# #####  * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ### Top Performing Schools (By Passing Rate)

# %%
# df.columns

# %%
# df

# %%
for school in df['school_name'].unique():  
    cur_school = df.loc[df['school_name'] == school]
    num_passing_math = len(cur_school.loc[cur_school['math_score']>=70])
    per_passing_math = (num_passing_math/len(cur_school['math_score']))*100
    rounded_per_p_math = round(per_passing_math, 2)
    math_result = f'{school}:{rounded_per_p_math}'
#     print(math_result)
#     print(rounded_per_p_math)

# %%
df_math_school = pd.DataFrame({
    "school_name" : ["Huang High School",
"Figueroa High School",
"Shelton High School",
"Hernandez High School",
"Griffin High School",
"Wilson High School",
"Cabrera High School",
"Bailey High School",
"Holden High School",
"Pena High School",
"Wright High School",
"Rodriguez High School",
"Johnson High School",
"Ford High School",
"Thomas High School"],
    "% Passing Math": [65.68,
65.99,
93.87,
66.75,
93.39,
93.87,
94.13,
66.68,
92.51,
94.59,
93.33,
66.37,
66.06,
68.31,
93.27]
})

# %%
for school in df['school_name'].unique():  
    cur_school = df.loc[df['school_name'] == school]
    num_passing_reading = len(cur_school.loc[cur_school['reading_score']>=70])
    per_passing_reading = (num_passing_reading/len(cur_school['reading_score']))*100
    rounded_per_p_reading = round(per_passing_reading, 2)
    reading_result = f'{school}:{rounded_per_p_reading}'
#     print(reading_result)
#     print(rounded_per_p_reading)

# %%
df_reading_school = pd.DataFrame({
    "school_name" : ["Huang High School",
"Figueroa High School",
"Shelton High School",
"Hernandez High School",
"Griffin High School",
"Wilson High School",
"Cabrera High School",
"Bailey High School",
"Holden High School",
"Pena High School",
"Wright High School",
"Rodriguez High School",
"Johnson High School",
"Ford High School",
"Thomas High School"],
    "% Passing Reading": [81.32,
80.74,
95.85,
80.86,
97.14,
96.54,
97.04,
81.93,
96.25,
95.95,
96.61,
80.22,
81.22,
79.3,
97.31]
})

# %%
# df_reading_school.groupby('school_name').first()

# %%
df1 = df.groupby('school_name').agg({
    "type":["first"],
    "Student ID": ["count"],
    "budget": ["first"],
    "math_score": ["mean"],
    "reading_score": ["mean"]   
})

# %%
df1.columns
# Out:
# MultiIndex([(         'type', 'first'),
#             (   'Student ID', 'count'),
#             (       'budget', 'first'),
#             (   'math_score',  'mean'),
#             ('reading_score',  'mean')],
#            )

# %%
df1 = df1.rename({(                         'type', 'first'):"School Type",(                   'Student ID', 'count'):"Total Students",(                       'budget', 'first'):
                  "Total School Budget",(                   'math_score',  'mean'):"Average Math Score",(                'reading_score',  'mean'):"Average Reading Score",(           'Per Student Budget',      ''):"Per Student Budget",('Spending Ranges (Per Student)',      ''):"Spending Ranges (Per Student)"
    
})

# %%
df1
# Out:
#                            type Student ID   budget math_score reading_score
#                           first      count    first       mean          mean
# school_name
# Bailey High School     District       4976  3124928  77.048432     81.033963
# Cabrera High School     Charter       1858  1081356  83.061895     83.975780
# Figueroa High School   District       2949  1884411  76.711767     81.158020
# Ford High School       District       2739  1763916  77.102592     80.746258
# Griffin High School     Charter       1468   917500  83.351499     83.816757
# Hernandez High School  District       4635  3022020  77.289752     80.934412
# Holden High School      Charter        427   248087  83.803279     83.814988
# Huang High School      District       2917  1910635  76.629414     81.182722
# Johnson High School    District       4761  3094650  77.072464     80.966394
# Pena High School        Charter        962   585858  83.839917     84.044699
# ...

# %%
# Calculation of "Per Student Budget"

# %%
df1['Per Student Budget'] = df1["budget","first"] / df1["Student ID", "count"]

# %%
# merging df1 dataframe to % math passing dataframe below

# %%
df2 =pd.merge(df1,df_math_school.groupby('school_name').first(), left_index=True, right_index =True)
# Out:
# /Users/memetbulut/.local/share/virtualenvs/pandas-challenge-IetGuPid/lib/python3.7/site-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
df2
# Out:
#                       (type, first)  (Student ID, count)  (budget, first)  \
# school_name
# Bailey High School         District                 4976          3124928
# Cabrera High School         Charter                 1858          1081356
# Figueroa High School       District                 2949          1884411
# Ford High School           District                 2739          1763916
# Griffin High School         Charter                 1468           917500
# Hernandez High School      District                 4635          3022020
# Holden High School          Charter                  427           248087
# Huang High School          District                 2917          1910635
# Johnson High School        District                 4761          3094650
# Pena High School            Charter                  962           585858
# Rodriguez High School      District                 3999          2547363
# ...

# %%
# merging df2 with df_reading_school

# %%
df2 = pd.merge(df2, df_reading_school.groupby('school_name').first(),left_index=True, right_index=True )

# %%
df2.columns
# Out:
# Index([         ('type', 'first'),    ('Student ID', 'count'),
#               ('budget', 'first'),     ('math_score', 'mean'),
#         ('reading_score', 'mean'), ('Per Student Budget', ''),
#                  '% Passing Math',        '% Passing Reading'],
#       dtype='object')

# %%
df2 = df2.rename(columns={('type', 'first'): "School Type", ('Student ID', 'count'):"Total Students",('budget', 'first'): "Total School Budget", ('math_score', 'mean'):"Average Math Score", ('reading_score', 'mean'):"Average Reading Score",
                         ('Per Student Budget', ''):"Per Student Budget"})

# %%
df2
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
df2['Overall Passing Rate']= (df2['% Passing Math'] + df2['% Passing Reading'])/2
# df2.rename(columns ={'type', 'first':'School Type', 'Student ID', 'count':"Total Students"})

# %% [markdown]
# # Top Performing Schools (By Passing Rate)

# %%
df2.sort_values('Overall Passing Rate', ascending =False).head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# school_name
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Pena High School        Charter             962               585858
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
#
#                      Average Math Score  Average Reading Score  \
# school_name
# Cabrera High School           83.061895              83.975780
# Thomas High School            83.418349              83.848930
# Pena High School              83.839917              84.044699
# Griffin High School           83.351499              83.816757
# Wilson High School            83.274201              83.989488
#
#                      Per Student Budget  % Passing Math  % Passing Reading  \
# school_name
# ...

# %% [markdown]
# # Bottom Performing Schools (By Passing Rate)

# %%
df2.sort_values('Overall Passing Rate', ascending =True).head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Ford High School         District            2739              1763916
#
#                        Average Math Score  Average Reading Score  \
# school_name
# Rodriguez High School           76.842711              80.744686
# Figueroa High School            76.711767              81.158020
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Ford High School                77.102592              80.746258
#
#                        Per Student Budget  % Passing Math  % Passing Reading  \
# school_name
# ...

# %%
# Math Scores by Grade
# Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

# Create a pandas series for each grade. Hint: use a conditional statement.

# Group each series by school

# Combine the series into a dataframe

# Optional: give the displayed data cleaner formatting

# %% [markdown]
# # Math Scores by Grade

# %%
df.groupby(['school_name', 'grade'])[['math_score']].agg(np.mean)
# Out:
#                              math_score
# school_name           grade
# Bailey High School    10th    76.996772
#                       11th    77.515588
#                       12th    76.492218
#                       9th     77.083676
# Cabrera High School   10th    83.154506
#                       11th    82.765560
#                       12th    83.277487
#                       9th     83.094697
# Figueroa High School  10th    76.539974
#                       11th    76.884344
#                       12th    77.151369
#                       9th     76.403037
# Ford High School      10th    77.672316
#                       11th    76.918058
#                       12th    76.179963
#                       9th     77.361345
# Griffin High School   10th    84.229064
#                       11th    83.842105
#                       12th    83.356164
#                       9th     82.044010
# Hernandez High School 10th    77.337408
#                       11th    77.136029
# ...

# %% [markdown]
# # Reading Scores by Grade

# %%
df.groupby(['school_name', 'grade'])[['reading_score']].agg(np.mean)
# Out:
#                              reading_score
# school_name           grade
# Bailey High School    10th       80.907183
#                       11th       80.945643
#                       12th       80.912451
#                       9th        81.303155
# Cabrera High School   10th       84.253219
#                       11th       83.788382
#                       12th       84.287958
#                       9th        83.676136
# Figueroa High School  10th       81.408912
#                       11th       80.640339
#                       12th       81.384863
#                       9th        81.198598
# Ford High School      10th       81.262712
#                       11th       80.403642
#                       12th       80.662338
#                       9th        80.632653
# Griffin High School   10th       83.706897
#                       11th       84.288089
#                       12th       84.013699
#                       9th        83.369193
# ...

# %% [markdown]
# # Scores by School Spending

# %%
# Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
# Average Math Score
# Average Reading Score
# % Passing Math
# % Passing Reading
# Overall Passing Rate (Average of the above two)

# %%
# creating bins
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
spending_per_student= pd.DataFrame(pd.cut(df1['Per Student Budget', ''], spending_bins, labels = group_names))
# spending_per_student

# %%
df7 = pd.merge(spending_per_student , df2, on="school_name")
df7.rename(columns={('Per Student Budget', ''):"Per Student Range"}).head()
# df7.columns
# Out:
#                      Per Student Range School Type  Total Students  \
# school_name
# Bailey High School            $615-645    District            4976
# Cabrera High School              <$585     Charter            1858
# Figueroa High School          $615-645    District            2949
# Ford High School              $615-645    District            2739
# Griffin High School           $615-645     Charter            1468
#
#                       Total School Budget  Average Math Score  \
# school_name
# Bailey High School                3124928           77.048432
# Cabrera High School               1081356           83.061895
# Figueroa High School              1884411           76.711767
# Ford High School                  1763916           77.102592
# Griffin High School                917500           83.351499
#
#                       Average Reading Score  Per Student Budget  \
# school_name
# Bailey High School                81.033963               628.0
# ...

# %% [markdown]
# ### Scores by School Spending

# %%
spending_Range_df = df7.groupby([('Per Student Budget', '')]).mean()[["Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","Overall Passing Rate"]]
spending_Range_df.round().rename(columns={('Per Student Budget', ''):"Per Student Range"})
# Out:
#                         Average Math Score  Average Reading Score  \
# (Per Student Budget, )
# <$585                                 83.0                   84.0
# $585-615                              84.0                   84.0
# $615-645                              79.0                   82.0
# $645-675                              77.0                   81.0
#
#                         % Passing Math  % Passing Reading  \
# (Per Student Budget, )
# <$585                             93.0               97.0
# $585-615                          94.0               96.0
# $615-645                          76.0               86.0
# $645-675                          66.0               81.0
#
#                         Overall Passing Rate
# (Per Student Budget, )
# <$585                                   95.0
# $585-615                                95.0
# $615-645                                81.0
# $645-675                                74.0

# %% [markdown]
# # Score by School Size

# %%
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
school_size = pd.DataFrame(pd.cut(df2["Total Students"], size_bins, labels = group_names))
school_size
# Out:
#                            Total Students
# school_name
# Bailey High School      Large (2000-5000)
# Cabrera High School    Medium (1000-2000)
# Figueroa High School    Large (2000-5000)
# Ford High School        Large (2000-5000)
# Griffin High School    Medium (1000-2000)
# Hernandez High School   Large (2000-5000)
# Holden High School          Small (<1000)
# Huang High School       Large (2000-5000)
# Johnson High School     Large (2000-5000)
# Pena High School            Small (<1000)
# Rodriguez High School   Large (2000-5000)
# Shelton High School    Medium (1000-2000)
# Thomas High School     Medium (1000-2000)
# Wilson High School      Large (2000-5000)
# Wright High School     Medium (1000-2000)

# %%
df8 = pd.merge(school_size , df2, on="school_name")
# df8.rename(columns={('Per Student Budget', ''):"Per Student Range"}).head()

# %%
# df8

schoo_size_df = df8.groupby(['Total Students_x']).mean()[["Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","Overall Passing Rate"]]

# %%
schoo_size_df
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Total Students_x
# Small (<1000)                83.821598              83.929843        93.55000
# Medium (1000-2000)           83.374684              83.864438        93.59800
# Large (2000-5000)            77.746417              81.344493        69.96375
#
#                     % Passing Reading  Overall Passing Rate
# Total Students_x
# Small (<1000)                96.10000                94.825
# Medium (1000-2000)           96.79000                95.194
# Large (2000-5000)            82.76625                76.365
